# %% [markdown]
# <a href="https://colab.research.google.com/github/jyryu3161/DrugDiscovery/blob/main/Lec12_chemprop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 데이터셋 확보

# %%
# !wget -O bbbp.zip https://www.dropbox.com/scl/fi/6kh2l30lxqh9l5y9kg9uj/bbbp.zip?rlkey=9aksfwk9tuem1jtq4cl4f9cfw&dl=0 # 데이터셋 다운로드
# !unzip bbbp.zip # 데이터셋 압축풀기
# Out:
# --2025-06-19 04:08:03--  https://www.dropbox.com/scl/fi/6kh2l30lxqh9l5y9kg9uj/bbbp.zip?rlkey=9aksfwk9tuem1jtq4cl4f9cfw
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com/cd/0/inline/Cr6lSpJXrNY1cuLjX824txU0Y7sZ3jHs0_8A9k_sf_5J0KdxQcBV4-G8sX307aTtNYHamI3H5UiUZ8nHILFAGFHIGQqtFeBSoP90uTJjWTkyiGXuVBmAcGg4OkiCzzAFs6FgpOfUtPsU6E4FdXMhHjJi/file# [following]
# --2025-06-19 04:08:03--  https://uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com/cd/0/inline/Cr6lSpJXrNY1cuLjX824txU0Y7sZ3jHs0_8A9k_sf_5J0KdxQcBV4-G8sX307aTtNYHamI3H5UiUZ8nHILFAGFHIGQqtFeBSoP90uTJjWTkyiGXuVBmAcGg4OkiCzzAFs6FgpOfUtPsU6E4FdXMhHjJi/file
# Resolving uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com (uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com (uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Cr7ScC0smu6vXpKoulHissUVPen7T8C3fWqspUDrP-vPlemE03O7lyUxos76PvQOmarOOrIVZnEPpXOBs3XrbN6tjE_IQdUeMXSddMtJH9ZCsFGLZb38WnZi_UVXU8iK7PD_e_GKvru0dAJYWm06TbuBcN9OolHsJpcZ0jZ7PGV4ChFrN2xgA94rxJzgN9oo10GfoSx2lw_XKExlbeL7YAYCUo3OTU8kxANs_-ECK2Sx5uhuwlxQndxGQ1yTxgG9Q-nU5YTlqtRAI-kXUNM9VsQpT59iT3usLbEnHxvvl8o4NdlXQ0seUMNKvey4-bXO-Opt3h9fHCblGlt00bV3ThfxxUKiKfCsRApYNPYdqHCVYDlXwtEYsemP3Lj-8-kFwVA/file [following]
# --2025-06-19 04:08:04--  https://uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com/cd/0/inline2/Cr7ScC0smu6vXpKoulHissUVPen7T8C3fWqspUDrP-vPlemE03O7lyUxos76PvQOmarOOrIVZnEPpXOBs3XrbN6tjE_IQdUeMXSddMtJH9ZCsFGLZb38WnZi_UVXU8iK7PD_e_GKvru0dAJYWm06TbuBcN9OolHsJpcZ0jZ7PGV4ChFrN2xgA94rxJzgN9oo10GfoSx2lw_XKExlbeL7YAYCUo3OTU8kxANs_-ECK2Sx5uhuwlxQndxGQ1yTxgG9Q-nU5YTlqtRAI-kXUNM9VsQpT59iT3usLbEnHxvvl8o4NdlXQ0seUMNKvey4-bXO-Opt3h9fHCblGlt00bV3ThfxxUKiKfCsRApYNPYdqHCVYDlXwtEYsemP3Lj-8-kFwVA/file
# Reusing existing connection to uc973dc2396812d292129e4f3785.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 50049 (49K) [application/zip]
# Saving to: ‘bbbp.zip’
#
# bbbp.zip            100%[===================>]  48.88K  --.-KB/s    in 0.01s
#
# 2025-06-19 04:08:04 (3.62 MB/s) - ‘bbbp.zip’ saved [50049/50049]
#
# Archive:  bbbp.zip
#   inflating: bbbp/test.csv
#   inflating: bbbp/train.csv
#   inflating: bbbp/valid.csv

# %% [markdown]
# ### 관련 패키지 설치

# %%
# !pip install chemprop
# !pip install molvs
# Out:
# Requirement already satisfied: chemprop in /usr/local/lib/python3.11/dist-packages (2.2.0)
# Requirement already satisfied: lightning>=2.0 in /usr/local/lib/python3.11/dist-packages (from chemprop) (2.5.1.post0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from chemprop) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from chemprop) (2.2.2)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/dist-packages (from chemprop) (2025.3.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from chemprop) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from chemprop) (1.15.3)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from chemprop) (2.6.0+cu124)
# Requirement already satisfied: astartes[molecules] in /usr/local/lib/python3.11/dist-packages (from chemprop) (1.3.1)
# Requirement already satisfied: ConfigArgParse in /usr/local/lib/python3.11/dist-packages (from chemprop) (1.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from chemprop) (13.9.4)
# Requirement already satisfied: descriptastorus in /usr/local/lib/python3.11/dist-packages (from chemprop) (2.8.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (2025.3.2)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (0.14.3)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (24.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (1.7.3)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (4.14.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning>=2.0->chemprop) (2.5.1.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->chemprop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->chemprop) (1.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from astartes[molecules]->chemprop) (0.9.0)
# Requirement already satisfied: aimsim_core in /usr/local/lib/python3.11/dist-packages (from astartes[molecules]->chemprop) (2.2.2)
# Requirement already satisfied: pandas-flavor in /usr/local/lib/python3.11/dist-packages (from descriptastorus->chemprop) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->chemprop) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->chemprop) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->chemprop) (2025.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit->chemprop) (11.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->chemprop) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->chemprop) (2.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->chemprop) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->chemprop) (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0->chemprop) (75.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->chemprop) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->chemprop) (1.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop) (5.9.5)
# Requirement already satisfied: padelpy in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop) (0.1.16)
# Requirement already satisfied: mhfp in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop) (1.9.6)
# Requirement already satisfied: mordredcommunity in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop) (2.0.6)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.11/dist-packages (from aimsim_core->astartes[molecules]->chemprop) (0.70.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1->chemprop) (3.0.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from pandas-flavor->descriptastorus->chemprop) (2025.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (1.20.1)
# Requirement already satisfied: dill>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from multiprocess>=0.70->aimsim_core->astartes[molecules]->chemprop) (0.3.7)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0->chemprop) (3.10)
# Collecting molvs
#   Downloading MolVS-0.1.1.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from molvs) (1.17.0)
# Building wheels for collected packages: molvs
#   Building wheel for molvs (setup.py) ... done
#   Created wheel for molvs: filename=MolVS-0.1.1-py3-none-any.whl size=32374 sha256=b32a278711be55120291cabd106de9e1c471d2661de6b920922c11a70ac0db88
#   Stored in directory: /root/.cache/pip/wheels/26/62/a4/147e264c789d9a4e8495f2c3d60f702425761f875bcfdf44e0
# Successfully built molvs
# Installing collected packages: molvs
# Successfully installed molvs-0.1.1

# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd
from rdkit import Chem
from molvs import Standardizer
from molvs.charge import Reionizer
from molvs.tautomer import TautomerCanonicalizer

from rdkit import RDLogger
import time

# RDKit의 로그 레벨을 ERROR로 설정하여 deprecation 경고 숨기기
RDLogger.logger().setLevel(RDLogger.ERROR)

def preprocess_smiles(smiles):
    """
    주어진 SMILES 문자열을 전처리합니다.

    :param smiles: 전처리할 SMILES 문자열
    :return: 전처리된 SMILES 문자열, 유효하지 않은 경우 None
    """
    # RDKit 분자 객체로 변환
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None  # 유효하지 않은 SMILES

    # MolVS 표준화 적용
    s = Standardizer()
    mol = s.standardize(mol)

    # 재이온화
    reionizer = Reionizer()
    mol = reionizer.reionize(mol)

    # 다시 SMILES로 변환
    return Chem.MolToSmiles(mol)

def preprocess_dataset(input_file, output_file):
    """
    입력 CSV 파일을 읽어 SMILES를 전처리하고 결과를 새 CSV 파일로 저장합니다.

    :param input_file: 입력 CSV 파일 경로
    :param output_file: 출력 CSV 파일 경로
    """
    # CSV 파일 읽기
    df = pd.read_csv(input_file)

    # SMILES 열이 있는지 확인
    if 'smiles' not in df.columns:
        raise ValueError("CSV 파일에 'smiles' 열이 없습니다.")

    # SMILES 전처리
    df['processed_smiles'] = df['smiles'].apply(preprocess_smiles)

    # 유효하지 않은 SMILES 제거
    df = df.dropna(subset=['processed_smiles'])

    # 결과를 새 CSV 파일로 저장
    df.to_csv(output_file, index=False)

# 데이터셋 전처리 실행
datasets = ['train', 'valid', 'test']

for dataset in datasets:
    input_file = f"./bbbp/{dataset}.csv"
    output_file = f"{dataset}_processed.csv"
    print(f"Processing {dataset} dataset...")
    preprocess_dataset(input_file, output_file)
    print(f"{dataset} dataset processing completed.")

print("All datasets have been processed.")
# Out:
# Processing train dataset...
# [04:20:56] Explicit valence for atom # 1 N, 4, is greater than permitted
# [04:20:56] Explicit valence for atom # 6 N, 4, is greater than permitted
# [04:20:57] Explicit valence for atom # 6 N, 4, is greater than permitted
# [04:20:57] Explicit valence for atom # 11 N, 4, is greater than permitted
# [04:20:58] Explicit valence for atom # 5 N, 4, is greater than permitted
# [04:21:01] Can't kekulize mol.  Unkekulized atoms: 12 14
# train dataset processing completed.
# Processing valid dataset...
# valid dataset processing completed.
# Processing test dataset...
# [04:21:02] Explicit valence for atom # 12 N, 4, is greater than permitted
# [04:21:02] Explicit valence for atom # 5 N, 4, is greater than permitted
# test dataset processing completed.
# All datasets have been processed.

# %% [markdown]
# ## Chemprop

# %% [markdown]
# https://chemprop.readthedocs.io/en/main/index.html

# %%
# 기존 CSV 파일 읽기
train_dataset = pd.read_csv('train_processed.csv')
valid_dataset = pd.read_csv('valid_processed.csv')
test_dataset = pd.read_csv('test_processed.csv')

# 데이터 전처리: 열 이름 변경 (필요한 경우)
for df in [train_dataset, valid_dataset, test_dataset]:
    if 'p_np' in df.columns:
        df.rename(columns={'p_np': 'label'}, inplace=True)
    if 'processed_smiles' not in df.columns:
        print("Error: 'smiles' column not found in the data")

# 전처리된 데이터를 CSV 파일로 다시 저장
train_dataset = train_dataset[['smiles', 'label']]
valid_dataset = valid_dataset[['smiles', 'label']]
test_dataset = test_dataset[['smiles', 'label']]

train_dataset.to_csv('train_processed_chemprop.csv', index=False)
valid_dataset.to_csv('valid_processed_chemprop.csv', index=False)
test_dataset.to_csv('test_processed_chemprop.csv', index=False)

# %%
# !chemprop train --data-path train_processed_chemprop.csv \
                --task-type classification \
                --output-dir chemprop_outputs
# Out:
# 2025-06-19T04:26:17 - INFO:chemprop.cli.main - Running in mode 'train' with args: {'smiles_columns': None, 'reaction_columns': None, 'no_header_row': False, 'num_workers': 0, 'batch_size': 64, 'accelerator': 'auto', 'devices': 'auto', 'rxn_mode': 'REAC_DIFF', 'multi_hot_atom_featurizer_mode': 'V2', 'keep_h': False, 'add_h': False, 'ignore_stereo': False, 'reorder_atoms': False, 'molecule_featurizers': None, 'descriptors_path': None, 'no_descriptor_scaling': False, 'no_atom_feature_scaling': False, 'no_atom_descriptor_scaling': False, 'no_bond_feature_scaling': False, 'no_bond_descriptor_scaling': False, 'atom_features_path': None, 'atom_descriptors_path': None, 'bond_features_path': None, 'bond_descriptors_path': None, 'constraints_path': None, 'constraints_to_targets': None, 'config_path': None, 'data_path': PosixPath('train_processed_chemprop.csv'), 'output_dir': PosixPath('chemprop_outputs'), 'remove_checkpoints': False, 'checkpoint': None, 'freeze_encoder': False, 'model_frzn': None, 'frzn_ffn_layers': 0, 'from_foundation': None, 'ensemble_size': 1, 'message_hidden_dim': 300, 'message_bias': False, 'depth': 3, 'undirected': False, 'dropout': 0.0, 'mpn_shared': False, 'aggregation': 'norm', 'aggregation_norm': 100, 'atom_messages': False, 'activation': 'RELU', 'activation_args': None, 'ffn_hidden_dim': 300, 'ffn_num_layers': 1, 'batch_norm': False, 'multiclass_num_classes': 3, 'atom_task_weights': None, 'atom_ffn_hidden_dim': 300, 'atom_ffn_num_layers': 1, 'atom_multiclass_num_classes': 3, 'bond_task_weights': None, 'bond_ffn_hidden_dim': 300, 'bond_ffn_num_layers': 1, 'bond_multiclass_num_classes': 3, 'atom_constrainer_ffn_hidden_dim': 300, 'atom_constrainer_ffn_num_layers': 1, 'bond_constrainer_ffn_hidden_dim': 300, 'bond_constrainer_ffn_num_layers': 1, 'weight_column': None, 'target_columns': None, 'mol_target_columns': None, 'atom_target_columns': None, 'bond_target_columns': None, 'ignore_columns': None, 'no_cache': False, 'splits_column': None, 'task_type': 'classification', 'loss_function': None, 'v_kl': 0.0, 'eps': 1e-08, 'alpha': 0.1, 'metrics': None, 'tracking_metric': 'val_loss', 'show_individual_scores': False, 'task_weights': None, 'warmup_epochs': 2, 'init_lr': 0.0001, 'max_lr': 0.001, 'final_lr': 0.0001, 'epochs': 50, 'patience': None, 'grad_clip': None, 'class_balance': False, 'split': 'RANDOM', 'split_sizes': [0.8, 0.1, 0.1], 'split_key_molecule': 0, 'num_replicates': 1, 'num_folds': None, 'save_smiles_splits': False, 'splits_file': None, 'data_seed': 0, 'pytorch_seed': None}
# Wrote config file to chemprop_outputs/config.toml
# 2025-06-19T04:26:17 - INFO:chemprop.cli.train - Pulling data from file: train_processed_chemprop.csv
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:17] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# [04:26:18] WARNING: not removing hydrogen atom without neighbors
# 2025-06-19T04:26:18 - WARNING:chemprop.data.splitting - The return type of make_split_indices has changed in v2.1 - see help(make_split_indices)
# 2025-06-19T04:26:18 - INFO:chemprop.cli.train - train/val/test split_0 sizes: [1307, 163, 164]
# 2025-06-19T04:26:18 - INFO:chemprop.cli.train -
#    Summary of Training Data
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Class ┃ Count/Percent label ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │   0.0 │             279/21% │
# │   1.0 │            1028/79% │
# │   NaN │                0/0% │
# │ Total │         1307/100.0% │
# └───────┴─────────────────────┘
#
# 2025-06-19T04:26:18 - INFO:chemprop.cli.train -
#   Summary of Validation Data
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Class ┃ Count/Percent label ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │   0.0 │              37/23% │
# │   1.0 │             126/77% │
# │   NaN │                0/0% │
# │ Total │          163/100.0% │
# └───────┴─────────────────────┘
#
# 2025-06-19T04:26:18 - INFO:chemprop.cli.train -
#      Summary of Test Data
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Class ┃ Count/Percent label ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │   0.0 │              32/20% │
# │   1.0 │             132/80% │
# │   NaN │                0/0% │
# │ Total │          164/100.0% │
# └───────┴─────────────────────┘
#
# 2025-06-19T04:26:19 - INFO:chemprop.cli.train - No loss function was specified! Using class default: <class 'chemprop.nn.metrics.BCELoss'>
# 2025-06-19T04:26:19 - INFO:chemprop.cli.train - MPNN(
#   (message_passing): BondMessagePassing(
#     (W_i): Linear(in_features=86, out_features=300, bias=False)
#     (W_h): Linear(in_features=300, out_features=300, bias=False)
#     (W_o): Linear(in_features=372, out_features=300, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (tau): ReLU()
#     (V_d_transform): Identity()
#     (graph_transform): GraphTransform(
#       (V_transform): Identity()
#       (E_transform): Identity()
#     )
#   )
#   (agg): NormAggregation()
#   (bn): Identity()
#   (predictor): BinaryClassificationFFN(
#     (ffn): MLP(
#       (0): Sequential(
#         (0): Linear(in_features=300, out_features=300, bias=True)
#       )
#       (1): Sequential(
#         (0): ReLU()
#         (1): Dropout(p=0.0, inplace=False)
#         (2): Linear(in_features=300, out_features=1, bias=True)
#       )
#     )
#     (criterion): BCELoss(task_weights=[[1.0]])
#     (output_transform): Identity()
#   )
#   (X_d_transform): Identity()
#   (metrics): ModuleList(
#     (0): BinaryAUROC()
#     (1): BCELoss(task_weights=[[1.0]])
#   )
# )
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-06-19 04:26:21.497521: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750307181.829893    6386 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750307181.919110    6386 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-19 04:26:22.578990: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py:310: The number of training batches (21) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#
#   | Name            | Type                    | Params | Mode
# --------------------------------------------------------------------
# 0 | message_passing | BondMessagePassing      | 227 K  | train
# 1 | agg             | NormAggregation         | 0      | train
# 2 | bn              | Identity                | 0      | train
# 3 | predictor       | BinaryClassificationFFN | 90.6 K | train
# 4 | X_d_transform   | Identity                | 0      | train
# 5 | metrics         | ModuleList              | 0      | train
# --------------------------------------------------------------------
# 318 K     Trainable params
# 0         Non-trainable params
# 318 K     Total params
# 1.273     Total estimated model params size (MB)
# 25        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100% 21/21 [00:06<00:00,  3.05it/s, v_num=0, train_loss_step=0.459]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.15it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.74it/s]
# Epoch 1: 100% 21/21 [00:04<00:00,  4.35it/s, v_num=0, train_loss_step=0.641, val_loss=0.667, train_loss_epoch=0.658]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.93it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.67it/s]
# Epoch 2: 100% 21/21 [00:08<00:00,  2.36it/s, v_num=0, train_loss_step=0.560, val_loss=0.576, train_loss_epoch=0.606]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.31it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.00it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.67it/s]
# Epoch 3: 100% 21/21 [00:06<00:00,  3.17it/s, v_num=0, train_loss_step=0.504, val_loss=0.530, train_loss_epoch=0.556]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.17it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  2.08it/s]
# Validation DataLoader 0: 100% 3/3 [00:01<00:00,  2.02it/s]
# Epoch 4: 100% 21/21 [00:08<00:00,  2.62it/s, v_num=0, train_loss_step=0.376, val_loss=0.544, train_loss_epoch=0.492]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  4.16it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.85it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  4.43it/s]
# Epoch 5: 100% 21/21 [00:05<00:00,  3.71it/s, v_num=0, train_loss_step=0.421, val_loss=0.423, train_loss_epoch=0.428]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.19it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.10it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.61it/s]
# Epoch 6: 100% 21/21 [00:05<00:00,  3.94it/s, v_num=0, train_loss_step=0.476, val_loss=0.419, train_loss_epoch=0.413]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.16it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.90it/s]
# Epoch 7: 100% 21/21 [00:04<00:00,  4.54it/s, v_num=0, train_loss_step=0.223, val_loss=0.396, train_loss_epoch=0.390]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.04it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.76it/s]
# Epoch 8: 100% 21/21 [00:05<00:00,  3.50it/s, v_num=0, train_loss_step=0.417, val_loss=0.397, train_loss_epoch=0.371]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.09it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.87it/s]
# Epoch 9: 100% 21/21 [00:04<00:00,  4.49it/s, v_num=0, train_loss_step=0.147, val_loss=0.380, train_loss_epoch=0.385]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.09it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.81it/s]
# Epoch 10: 100% 21/21 [00:07<00:00,  2.89it/s, v_num=0, train_loss_step=0.487, val_loss=0.386, train_loss_epoch=0.358]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.92it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.64it/s]
# Epoch 11: 100% 21/21 [00:04<00:00,  4.53it/s, v_num=0, train_loss_step=0.208, val_loss=0.373, train_loss_epoch=0.359]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.15it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.96it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.72it/s]
# Epoch 12: 100% 21/21 [00:05<00:00,  3.85it/s, v_num=0, train_loss_step=0.263, val_loss=0.361, train_loss_epoch=0.349]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.33it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.21it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.70it/s]
# Epoch 13: 100% 21/21 [00:04<00:00,  4.23it/s, v_num=0, train_loss_step=0.211, val_loss=0.374, train_loss_epoch=0.339]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.05it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.80it/s]
# Epoch 14: 100% 21/21 [00:07<00:00,  2.92it/s, v_num=0, train_loss_step=0.273, val_loss=0.365, train_loss_epoch=0.331]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  2.57it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  2.39it/s]
# Validation DataLoader 0: 100% 3/3 [00:01<00:00,  2.50it/s]
# Epoch 15: 100% 21/21 [00:06<00:00,  3.02it/s, v_num=0, train_loss_step=0.178, val_loss=0.353, train_loss_epoch=0.329]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  4.76it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.86it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.58it/s]
# Epoch 16: 100% 21/21 [00:05<00:00,  3.79it/s, v_num=0, train_loss_step=0.241, val_loss=0.362, train_loss_epoch=0.325]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  2.82it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  2.85it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.35it/s]
# Epoch 17: 100% 21/21 [00:05<00:00,  3.80it/s, v_num=0, train_loss_step=0.239, val_loss=0.346, train_loss_epoch=0.323]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.97it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.76it/s]
# Epoch 18: 100% 21/21 [00:04<00:00,  4.22it/s, v_num=0, train_loss_step=0.162, val_loss=0.353, train_loss_epoch=0.313]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.26it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.09it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.84it/s]
# Epoch 19: 100% 21/21 [00:06<00:00,  3.46it/s, v_num=0, train_loss_step=0.298, val_loss=0.342, train_loss_epoch=0.307]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.21it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.09it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.85it/s]
# Epoch 20: 100% 21/21 [00:04<00:00,  4.51it/s, v_num=0, train_loss_step=0.401, val_loss=0.348, train_loss_epoch=0.313]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.32it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.13it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.90it/s]
# Epoch 21: 100% 21/21 [00:06<00:00,  3.50it/s, v_num=0, train_loss_step=0.231, val_loss=0.340, train_loss_epoch=0.304]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.32it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.08it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.90it/s]
# Epoch 22: 100% 21/21 [00:04<00:00,  4.47it/s, v_num=0, train_loss_step=0.332, val_loss=0.336, train_loss_epoch=0.302]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.01it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.74it/s]
# Epoch 23: 100% 21/21 [00:04<00:00,  4.25it/s, v_num=0, train_loss_step=0.264, val_loss=0.349, train_loss_epoch=0.303]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.17it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.08it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.60it/s]
# Epoch 24: 100% 21/21 [00:05<00:00,  3.88it/s, v_num=0, train_loss_step=0.247, val_loss=0.345, train_loss_epoch=0.298]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.15it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.79it/s]
# Epoch 25: 100% 21/21 [00:04<00:00,  4.47it/s, v_num=0, train_loss_step=0.381, val_loss=0.334, train_loss_epoch=0.291]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.84it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.61it/s]
# Epoch 26: 100% 21/21 [00:05<00:00,  3.50it/s, v_num=0, train_loss_step=0.195, val_loss=0.333, train_loss_epoch=0.297]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.23it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.93it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.69it/s]
# Epoch 27: 100% 21/21 [00:04<00:00,  4.53it/s, v_num=0, train_loss_step=0.230, val_loss=0.334, train_loss_epoch=0.289]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.89it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.70it/s]
# Epoch 28: 100% 21/21 [00:05<00:00,  3.58it/s, v_num=0, train_loss_step=0.213, val_loss=0.334, train_loss_epoch=0.277]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.36it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.58it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  4.41it/s]
# Epoch 29: 100% 21/21 [00:04<00:00,  4.49it/s, v_num=0, train_loss_step=0.401, val_loss=0.333, train_loss_epoch=0.279]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  4.82it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.80it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.57it/s]
# Epoch 30: 100% 21/21 [00:04<00:00,  4.38it/s, v_num=0, train_loss_step=0.328, val_loss=0.330, train_loss_epoch=0.274]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.49it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.21it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.68it/s]
# Epoch 31: 100% 21/21 [00:05<00:00,  3.74it/s, v_num=0, train_loss_step=0.315, val_loss=0.324, train_loss_epoch=0.268]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.04it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.80it/s]
# Epoch 32: 100% 21/21 [00:04<00:00,  4.46it/s, v_num=0, train_loss_step=0.238, val_loss=0.326, train_loss_epoch=0.263]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.14it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.03it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.73it/s]
# Epoch 33: 100% 21/21 [00:06<00:00,  3.43it/s, v_num=0, train_loss_step=0.235, val_loss=0.330, train_loss_epoch=0.264]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.08it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.80it/s]
# Epoch 34: 100% 21/21 [00:04<00:00,  4.46it/s, v_num=0, train_loss_step=0.366, val_loss=0.346, train_loss_epoch=0.265]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.12it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.75it/s]
# Epoch 35: 100% 21/21 [00:05<00:00,  3.55it/s, v_num=0, train_loss_step=0.549, val_loss=0.328, train_loss_epoch=0.253]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.55it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.62it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  4.49it/s]
# Epoch 36: 100% 21/21 [00:06<00:00,  3.34it/s, v_num=0, train_loss_step=0.305, val_loss=0.326, train_loss_epoch=0.253]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  2.77it/s]
# Validation DataLoader 0:  67% 2/3 [00:01<00:00,  1.70it/s]
# Validation DataLoader 0: 100% 3/3 [00:02<00:00,  1.44it/s]
# Epoch 37: 100% 21/21 [00:08<00:00,  2.61it/s, v_num=0, train_loss_step=0.268, val_loss=0.324, train_loss_epoch=0.260]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.94it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.73it/s]
# Epoch 38: 100% 21/21 [00:04<00:00,  4.41it/s, v_num=0, train_loss_step=0.253, val_loss=0.323, train_loss_epoch=0.250]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.16it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.92it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.67it/s]
# Epoch 39: 100% 21/21 [00:06<00:00,  3.45it/s, v_num=0, train_loss_step=0.137, val_loss=0.325, train_loss_epoch=0.248]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.08it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.82it/s]
# Epoch 40: 100% 21/21 [00:04<00:00,  4.45it/s, v_num=0, train_loss_step=0.180, val_loss=0.321, train_loss_epoch=0.250]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.12it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.86it/s]
# Epoch 41: 100% 21/21 [00:05<00:00,  4.04it/s, v_num=0, train_loss_step=0.344, val_loss=0.324, train_loss_epoch=0.243]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.36it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.20it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.69it/s]
# Epoch 42: 100% 21/21 [00:05<00:00,  3.96it/s, v_num=0, train_loss_step=0.337, val_loss=0.326, train_loss_epoch=0.240]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.06it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.79it/s]
# Epoch 43: 100% 21/21 [00:04<00:00,  4.42it/s, v_num=0, train_loss_step=0.159, val_loss=0.318, train_loss_epoch=0.238]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.17it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.89it/s]
# Epoch 44: 100% 21/21 [00:06<00:00,  3.47it/s, v_num=0, train_loss_step=0.122, val_loss=0.317, train_loss_epoch=0.239]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.87it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.69it/s]
# Epoch 45: 100% 21/21 [00:04<00:00,  4.45it/s, v_num=0, train_loss_step=0.162, val_loss=0.321, train_loss_epoch=0.233]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.91it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.64it/s]
# Epoch 46: 100% 21/21 [00:06<00:00,  3.48it/s, v_num=0, train_loss_step=0.180, val_loss=0.318, train_loss_epoch=0.229]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.08it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  4.97it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.72it/s]
# Epoch 47: 100% 21/21 [00:04<00:00,  4.44it/s, v_num=0, train_loss_step=0.175, val_loss=0.317, train_loss_epoch=0.230]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.26it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.03it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.78it/s]
# Epoch 48: 100% 21/21 [00:05<00:00,  3.95it/s, v_num=0, train_loss_step=0.259, val_loss=0.318, train_loss_epoch=0.230]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  3.39it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  3.21it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  3.73it/s]
# Epoch 49: 100% 21/21 [00:05<00:00,  4.09it/s, v_num=0, train_loss_step=0.311, val_loss=0.318, train_loss_epoch=0.227]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33% 1/3 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  67% 2/3 [00:00<00:00,  5.14it/s]
# Validation DataLoader 0: 100% 3/3 [00:00<00:00,  5.88it/s]
# Epoch 49: 100% 21/21 [00:05<00:00,  3.71it/s, v_num=0, train_loss_step=0.311, val_loss=0.319, train_loss_epoch=0.225]`Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100% 21/21 [00:05<00:00,  3.70it/s, v_num=0, train_loss_step=0.311, val_loss=0.319, train_loss_epoch=0.225]
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/connectors/checkpoint_connector.py:149: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at /content/chemprop_outputs/model_0/checkpoints/best-epoch=43-val_loss=0.32.ckpt
# Loaded model weights from the checkpoint at /content/chemprop_outputs/model_0/checkpoints/best-epoch=43-val_loss=0.32.ckpt
# Predicting DataLoader 0: 100% 3/3 [00:00<00:00,  8.70it/s]
# 2025-06-19T04:31:46 - INFO:chemprop.cli.train - Test Set results:
# 2025-06-19T04:31:46 - INFO:chemprop.cli.train - test/roc: 0.8745265603065491
# 2025-06-19T04:31:46 - INFO:chemprop.cli.train - Best model saved to 'chemprop_outputs/model_0/best.pt'

# %%
# 학습된 모델을 사용하여 테스트 세트에 대한 예측 수행
# !chemprop predict --test-path test_processed_chemprop.csv \
                  --preds-path  chemprop_predictions.csv \
                  --model-path ./chemprop_outputs/model_0/best.pt
# Out:
# 2025-06-19T04:33:20 - INFO:chemprop.cli.main - Running in mode 'predict' with args: {'smiles_columns': None, 'reaction_columns': None, 'no_header_row': False, 'num_workers': 0, 'batch_size': 64, 'accelerator': 'auto', 'devices': 'auto', 'rxn_mode': 'REAC_DIFF', 'multi_hot_atom_featurizer_mode': 'V2', 'keep_h': False, 'add_h': False, 'ignore_stereo': False, 'reorder_atoms': False, 'molecule_featurizers': None, 'descriptors_path': None, 'no_descriptor_scaling': False, 'no_atom_feature_scaling': False, 'no_atom_descriptor_scaling': False, 'no_bond_feature_scaling': False, 'no_bond_descriptor_scaling': False, 'atom_features_path': None, 'atom_descriptors_path': None, 'bond_features_path': None, 'bond_descriptors_path': None, 'constraints_path': None, 'constraints_to_targets': None, 'test_path': PosixPath('test_processed_chemprop.csv'), 'output': PosixPath('chemprop_predictions.csv'), 'drop_extra_columns': False, 'model_paths': [PosixPath('chemprop_outputs/model_0/best.pt')], 'cal_path': None, 'uncertainty_method': 'none', 'calibration_method': None, 'evaluation_methods': None, 'uncertainty_dropout_p': 0.1, 'dropout_sampling_size': 10, 'calibration_interval_percentile': 95, 'conformal_alpha': 0.1, 'cal_descriptors_path': None, 'cal_atom_features_path': None, 'cal_atom_descriptors_path': None, 'cal_bond_features_path': None, 'cal_bond_descriptors_path': None, 'cal_constraints_path': None}
# [04:33:20] WARNING: not removing hydrogen atom without neighbors
# [04:33:20] WARNING: not removing hydrogen atom without neighbors
# [04:33:20] WARNING: not removing hydrogen atom without neighbors
# [04:33:20] WARNING: not removing hydrogen atom without neighbors
# 2025-06-19T04:33:20 - INFO:chemprop.cli.predict - test size: 192
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100% 3/3 [00:00<00:00,  5.69it/s]
# 2025-06-19T04:33:21 - INFO:chemprop.cli.predict - Predictions saved to 'chemprop_predictions.csv'

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, roc_auc_score, matthews_corrcoef, precision_score, recall_score

def evaluate_model(y, y_pred_proba):
    y_pred = (y_pred_proba > 0.5).astype(int)  # 확률을 이진 예측으로 변환

    acc = accuracy_score(y, y_pred)
    auroc = roc_auc_score(y, y_pred_proba)  # ROC AUC는 확률 값을 사용
    mcc = matthews_corrcoef(y, y_pred)
    precision = precision_score(y, y_pred)
    recall = recall_score(y, y_pred)

    return {
        "ACC": acc,
        "AUROC": auroc,
        "MCC": mcc,
        "Precision": precision,
        "Recall": recall
    }

ground_truth_df = pd.read_csv('test_processed_chemprop.csv')
pred_df = pd.read_csv('chemprop_predictions.csv')

ground_truth_df['pred'] = pred_df['label']

y = ground_truth_df['label'].values  # 'p_np'가 실제 레이블 컬럼명이라고 가정
y_pred_proba = pred_df['label'].values  # 'p_np'가 예측 확률 컬럼명이라고 가정

print(evaluate_model(y, y_pred_proba))

ground_truth_df
# Out:
# {'ACC': 0.8385416666666666, 'AUROC': np.float64(0.8950819672131147), 'MCC': np.float64(0.6486876995404717), 'Precision': 0.8181818181818182, 'Recall': 0.9590163934426229}
#                                                 smiles  label      pred
# 0                                              C(Cl)Cl      1  0.879012
# 1    c1cc2c(cc(CC3=CNC(=NC3=O)NCCSCc3oc(cc3)CN(C)C)...      0  0.677595
# 2                          CCOC(=O)c1cncn1C(C)c2ccccc2      1  0.784569
# 3                          CN(C)c1cc(C2=NC(N)=NN2)ccn1      0  0.909329
# 4              N1(Cc2cc(OCCCNc3oc4ccccc4n3)ccc2)CCCCC1      1  0.966866
# ..                                                 ...    ...       ...
# 187   C1=C([S](N)(=O)=O)C=CC(=C1C(NCC2N(CCC2)CCC)=O)OC      1  0.856452
# 188  C4=C(C(C3CCN(CCC1=C(N=C2N(C1=O)CCS2)C)CC3)=O)C...      1  0.953386
# 189  [C@]14([C@](OC(=O)CC)([C@@H](CC1C3[C@@](F)(C2(...      1  0.995810
# 190  C1=CC=C2C(=C1)SC3=C(N2CC(C)CN(C)C)C=C(C=C3)C(F...      1  0.997778
# 191  [C@H]13N([C@H](CC(C1)NC(C2=CC=CC(=C2OC)OC)=O)C...      1  0.785628
#
# [192 rows x 3 columns]
